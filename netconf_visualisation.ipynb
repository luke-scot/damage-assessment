# %% [markdown]
# # Beirut damage propagated in NetConf
# This notebook aims to get Beirut damage data associated with satellite imagery and run belief propagation on the data using NetConf

# %%
# Installs 
#%pip install rioxarray xarray earthpy

# Package imports
import math
import json
import requests
import os
import ipyleaflet
import PIL
import numpy as np
import pandas as pd
import geopandas as gpd
import rasterio as ro
import rioxarray as rxr
import xarray as xr
# import earthpy as et
# import earthpy.plot as ep
import matplotlib.pyplot as plt
from base64 import b64encode
from io import BytesIO
from tqdm import tqdm
from ipywidgets import HTML
from ipyleaflet import Map, basemaps, GeoData, CircleMarker, Popup, GeoJSON, LegendControl, ImageOverlay
from rasterio.plot import show
from IPython.display import Image, display
from shapely.geometry import Polygon, Point, mapping

import descarteslabs as dl
import descarteslabs.workflows as wf

import netconf.netconf as nc

# %%
# Define variables
# Location variables
lat, lon, zoom = 33.8975, 35.5063, 14 # Map properties

# Building Footprints variables
buildings = "./data/beirutBuildingFootprints.geojson"

# Damage Assessment variables
dataFile = "./data/geopalData.csv" # GeoPal data

# Interferogram paths
ifgPath = "./data/20200730_20200805_IW1_Stack_ifg_deb_dinsar_flt_ML_TC_big.tif"
croppedPath = "./data/croppedIfg.png"

# A priori damage beliefs (green, yellow, red decisions)
gb, yb, rb = 0.1, 0.7, 0.95
ratioWeight = 1

# %% [markdown]
# _____________
# ## 1 - Import Ground Datasets

# %%
# Import footprints geojson
# Display header 
builds = gpd.read_file(buildings)
pd.set_option('display.max_columns', None)
fps = gpd.GeoDataFrame(builds[['id','building','name']], geometry=builds.geometry)
fps.head()
# Out:
#                  id     building                        name  \
# 0    relation/71853          yes                        None
# 1  relation/6678216  residential                        None
# 2  relation/6996546       school  Collège des Trois Docteurs
# 3  relation/7000797       school           كلية القلب الأقدس
# 4  relation/7026674          yes                        None
#
#                                             geometry
# 0  POLYGON ((35.4894536 33.8946995, 35.4894132 33...
# 1  POLYGON ((35.524633 33.8898401, 35.5246194 33....
# 2  POLYGON ((35.5185524 33.8949802, 35.5185834 33...
# 3  (POLYGON ((35.5106324 33.895221, 35.5106476 33...
# 4  POLYGON ((35.5053153 33.893788, 35.5048335 33....

# %%
# Import GeoPal data
allData = pd.read_csv(dataFile)
# Extract locations from joint column in database
locations, mapPoints = allData['get location - الموقع_w_2049198'], allData['point on map - الموقع على الخريطة_w_2049199']
lats, lons = np.zeros([len(locations), 1]),  np.zeros([len(locations), 1])
for i in range(len(locations)):
    loc = locations[i]
    if type(loc) is float or (type(loc) is str and loc[0].isalpha()):
        mp = mapPoints[i]
        if type(mp) is str and mp[0].isdigit():
            try: lats[i], lons[i] = mp.split(' ')[0], mp.split(' ')[1]
            except: lats[i], lons[i] = mp.split(',')[0], mp.split(',')[1] # Deal with rogue commas instead of space
    else: lats[i], lons[i] = loc.split(' ')[0], loc.split(' ')[1]

# Extract columns of useful data
data = pd.DataFrame({
    'id': allData['Job ID'],
    'area': allData['plot area - المنطقة العقارية_w_2049201'],
    'damage': allData['structural damage level - مستوى الضرر الأنشائي للمبنى_w_2049205'],
    'floors': allData['number of floors - عدد الطوابق_w_2049208'],
    'units': allData['number of units - عدد الشقق_w_2049209'],
    'use': allData['building use - وجهة الاستعمال للمبنى_w_2049210'],
    'photos': allData['take pictures - التقاط صور_w_2049222'],
    'decision': allData['decision - القرار_w_2049224']    
})

# Create geodatabase merging locations with useful data
assessments = gpd.GeoDataFrame(data, geometry=gpd.points_from_xy(lons, lats),crs={'init': 'epsg:4326'})

# Filter for non located values
locs = assessments[assessments.geometry.x != 0]
locs.head()
# Out:
#     id                  area  \
# 0  278  El Bachoura الباشورة
# 2  280    Achrafieh الأشرفية
# 3  281    Achrafieh الأشرفية
# 5  283    Achrafieh الأشرفية
# 6  284    Achrafieh الأشرفية
#
#                                               damage  floors  units  \
# 0                                                NaN     NaN    NaN
# 2                                                NaN     NaN    NaN
# 3  Partially destroyed (poses a public safety haz...     5.0    5.0
# 5  Partially destroyed (poses a public safety haz...     4.0    5.0
# 6  Partially destroyed (poses a public safety haz...     4.0    8.0
#
#                                  use  \
# 0                                NaN
# 2                                NaN
# 3  Residential سكني,Commercial تجاري
# 5  Residential سكني,Commercial تجاري
# 6  Residential سكني,Commercial تجاري
#
#                                               photos  \
# 0  https://app.geopalsolutions.com/jobs/viewworkf...
# 2  https://app.geopalsolutions.com/jobs/viewworkf...
# 3                                                NaN
# 5  https://app.geopalsolutions.com/jobs/viewworkf...
# 6  https://app.geopalsolutions.com/jobs/viewworkf...
#
#                                        decision                       geometry
# 0                                           NaN  POINT (35.5577379 33.8830089)
# 2                                           NaN   POINT (35.557755 33.8830024)
# 3                                           NaN  POINT (35.5577587 33.8830063)
# 5  YELLOW (restricted use) أصفر (لا يصلح للسكن)  POINT (35.5577435 33.8830157)
# 6  YELLOW (restricted use) أصفر (لا يصلح للسكن)  POINT (35.5577312 33.8829998)

# %% [markdown]
# ____________
# ## 2 - Combine building footprints with damage assessments

# %%
# Get joint geodataframe of building footprints with damage assessments
joint = gpd.sjoin(fps, locs, how="left", op='contains').dropna(subset=['decision'])
joint.head()
# Out:
#              id_left     building      name  \
# 1   relation/6678216  residential      None
# 19  relation/7460523          yes  العاملية
# 24  relation/7803503          yes      None
# 24  relation/7803503          yes      None
# 27  relation/8056967          yes      None
#
#                                              geometry  index_right id_right  \
# 1   POLYGON ((35.524633 33.8898401, 35.5246194 33....       1111.0     2108
# 19  (POLYGON ((35.5059967 33.8827747, 35.5056111 3...       5630.0    10808
# 24  POLYGON ((35.4971487 33.8855667, 35.4971174 33...       5520.0    10670
# 24  POLYGON ((35.4971487 33.8855667, 35.4971174 33...       5505.0    10652
# 27  POLYGON ((35.5222517 33.8889111, 35.5217716 33...        811.0     1300
#
#                     area                    damage  floors  units  \
# 1     Achrafieh الأشرفية  Not affected - غير متأذي     3.0    NaN
# 19     El Mazraa المزرعة  Not affected - غير متأذي     5.0    4.0
# 24  El Msaytbeh المصيطبة  Not affected - غير متأذي     7.0    NaN
# 24  El Msaytbeh المصيطبة  Not affected - غير متأذي     8.0    NaN
# 27    Achrafieh الأشرفية  Not affected - غير متأذي     2.0    NaN
#
#                                    use  \
# 1                     Residential سكني
# 19  Commercial تجاري, Residential سكني
# 24                                 NaN
# 24                    Residential سكني
# 27                    Residential سكني
#
#                                                photos  \
# 1   https://app.geopalsolutions.com/jobs/viewworkf...
# 19  https://app.geopalsolutions.com/jobs/viewworkf...
# 24  https://app.geopalsolutions.com/jobs/viewworkf...
# 24  https://app.geopalsolutions.com/jobs/viewworkf...
# 27  https://app.geopalsolutions.com/jobs/viewworkf...
#
#                               decision
# 1   GREEN (inspected) أخضر (تم دراسته)
# 19  GREEN (inspected) أخضر (تم دراسته)
# 24  GREEN (inspected) أخضر (تم دراسته)
# 24  GREEN (inspected) أخضر (تم دراسته)
# 27  GREEN (inspected) أخضر (تم دراسته)

# %%
def to_geodata(gdf, color):
    plotGdf = GeoData(geo_dataframe = gdf,
                          style={'color': color, 'radius':2, 'fillColor': color, 'opacity':0.9, 'weight':1.9, 'dashArray':'2', 'fillOpacity':0.7},
                          hover_style={'fillColor': 'white' , 'fillOpacity': 0.2},
                          point_style={'radius': 3, 'color': color, 'fillOpacity': 0.8, 'fillColor': color, 'weight': 3},
                          name = 'Images')
    return plotGdf

# %%
m1 = Map(basemap=basemaps.OpenStreetMap.Mapnik, center=[lat, lon], zoom=zoom, scroll_wheel_zoom=True)
m1.add_layer(to_geodata(joint.loc[joint['decision'] == 'GREEN (inspected) أخضر (تم دراسته)'],'green'))
m1.add_layer(to_geodata(joint.loc[joint['decision'] == 'YELLOW (restricted use) أصفر (لا يصلح للسكن)'],'yellow'))
m1.add_layer(to_geodata(joint.loc[joint['decision'] == 'RED (unsafe/evacuate) أحمر (غير آمن/للاخلاء)ء'],'red'))

if not 'l1' in globals(): # Add legend if forming map for first time
    l1 = legend = LegendControl({"No Restrictions":"#008000", "Restricted Use":"#FFFF00", "Unsafe/Evacuated":"#FF0000", "No Decision":"#0000FF"}, name="Decision", position="bottomleft")
    m1.add_control(l1)
m1
# Out:
# Map(center=[33.8975, 35.5063], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zo…

# %%
# Display map upon which to draw Polygon for analysis
r = 0.01
testPoly = ipyleaflet.Polygon(locations=[(lat-r, lon-r), (lat-r, lon+r), (lat+r, lon+r),(lat+r, lon-r)], color="yellow", fill_color="yellow", transform=True)

m1.add_layer(testPoly)

# %% [markdown]
# ____________
# ## 3 - Pixel values from interferogram

# %%
# Import interferogram
wholeIfg = rxr.open_rasterio(ifgPath, masked=True).squeeze()

# Define AOI
poly = Polygon([[p['lng'], p['lat']] for p in testPoly.locations[0]])

# Plot AOI on whole interferogram
f, ax = plt.subplots(figsize=(10, 5))
wholeIfg.plot.imshow(ax=ax)
extent = gpd.GeoSeries([poly])
extent.plot(ax=ax, alpha=.8, color = 'yellow')
ax.set(title="Area of interest overlayed on interferogram")
ax.set_axis_off()
plt.show()

# %%
# Plot cropped interferogram
croppedIfg = wholeIfg.rio.clip(extent.geometry.apply(mapping), extent.crs)

f, ax = plt.subplots(figsize=(10, 4))
croppedIfg.plot(ax=ax)
ax.set(title="Interferogram cropped to area of interest")
plt.show()

# Plot interferogram on basemap
def image_overlay(url, bounds, name):
    """Overlays an image from the Internet or locally on the map.
    Args:
        url (str): http URL or local file path to the image.
        bounds (tuple): bounding box of the image in the format of (lower_left(lat, lon), upper_right(lat, lon)), such as ((13, -130), (32, -100)).
        name (str): name of the layer to show on the layer control.
    """
    if not url.startswith('http'):
        ext, image, f = os.path.splitext(url)[1][1:], PIL.Image.open(url), BytesIO()  # file extension
        image.save(f, ext)
        data = b64encode(f.getvalue()).decode('ascii')
        url = 'data:image/{};base64,'.format(ext) + data
        
    return ImageOverlay(url=url, bounds=bounds, name=name)

m2 = Map(basemap=basemaps.OpenStreetMap.Mapnik, center=[lat, lon], zoom=zoom+1, scroll_wheel_zoom=True)
PIL.Image.fromarray((croppedIfg.data*255).astype('uint8')).convert('RGB').save(croppedPath)
bounds = (min(np.array(croppedIfg.y)), min(np.array(croppedIfg.x))), (max(np.array(croppedIfg.y)), max(np.array(croppedIfg.x)))
image = image_overlay(url=croppedPath, bounds=bounds, name = 'Interferogram')
m2.add_layer(image)
m2
# Out:
# Map(center=[33.8975, 35.5063], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zo…

# %% [markdown]
# ________________
# ## 4 - Associate damage belief with pixels as nodes

# %%
named = croppedIfg.rename('ifg')
df = named.to_dataframe()
coords = np.concatenate(np.array(df.axes[0]))
initial = gpd.GeoDataFrame(pd.DataFrame(np.concatenate((np.ones([len(df),2])*0.5, np.array(df['ifg']).reshape(-1,1)), axis=1), columns = ['noDmg','dmg','ifg']), geometry=gpd.points_from_xy(coords[1::2], coords[0::2]),crs={'init': 'epsg:4326'})

# %%
# Assign updated beliefs to pixels within assessed building footprints
nodes = gpd.sjoin(initial, joint[['geometry','decision']], how='left', op='within')
nodes = nodes[~nodes.index.duplicated(keep='first')]
nodes.loc[nodes.decision == 'GREEN (inspected) أخضر (تم دراسته)', ['noDmg', 'dmg']] = 1-gb, gb
nodes.loc[nodes.decision == 'YELLOW (restricted use) أصفر (لا يصلح للسكن)', ['noDmg', 'dmg']] = 1-yb, yb
nodes.loc[nodes.decision == 'RED (unsafe/evacuate) أحمر (غير آمن/للاخلاء)ء', ['noDmg', 'dmg']] = 1-rb, rb
nodes.head()
# Out:
#    noDmg  dmg       ifg                                     geometry  \
# 0    0.5  0.5 -0.990563  POINT (35.48206612568754 33.89638152588353)
# 1    0.5  0.5 -0.912629  POINT (35.48219162033273 33.89638152588353)
# 2    0.5  0.5 -0.859307  POINT (35.48231711497792 33.89638152588353)
# 3    0.5  0.5 -0.895607  POINT (35.48244260962311 33.89638152588353)
# 4    0.5  0.5 -0.948094   POINT (35.4825681042683 33.89638152588353)
#
#    index_right decision
# 0          NaN      NaN
# 1          NaN      NaN
# 2          NaN      NaN
# 3          NaN      NaN
# 4          NaN      NaN

# %%
# Show example of green decision nodes
nodes.loc[nodes.decision == 'GREEN (inspected) أخضر (تم دراسته)']
# Out:
#      noDmg  dmg       ifg                                     geometry  \
# 51     0.9  0.1  0.705952  POINT (35.49474108485188 33.89475009549604)
# 108    0.9  0.1  0.115271  POINT (35.49725097775571 33.89462460085085)
# 145    0.9  0.1  0.120061  POINT (35.49725097775571 33.89449910620566)
# 277    0.9  0.1  0.151529  POINT (35.49524306343265 33.89399712762489)
# 279    0.9  0.1  0.050381  POINT (35.49549405272302 33.89399712762489)
# 316    0.9  0.1 -0.001275   POINT (35.49549405272302 33.8938716329797)
# 325    0.9  0.1 -0.207282   POINT (35.49662350452975 33.8938716329797)
# 326    0.9  0.1 -0.037754   POINT (35.49674899917494 33.8938716329797)
# 344    0.9  0.1  0.384521  POINT (35.49436460091631 33.89374613833451)
# 345    0.9  0.1  0.358767   POINT (35.4944900955615 33.89374613833451)
# 346    0.9  0.1  0.365778  POINT (35.49461559020668 33.89374613833451)
# 361    0.9  0.1 -0.642412  POINT (35.49649800988456 33.89374613833451)
# 362    0.9  0.1 -0.358822  POINT (35.49662350452975 33.89374613833451)
# 374    0.9  0.1  0.174827  POINT (35.49348613839997 33.89362064368932)
# 375    0.9  0.1  0.301967  POINT (35.49361163304516 33.89362064368932)
# 382    0.9  0.1  0.233771   POINT (35.4944900955615 33.89362064368932)
# 393    0.9  0.1 -0.105471   POINT (35.4958705366586 33.89362064368932)
# 394    0.9  0.1 -0.121394   POINT (35.4959960313038 33.89362064368932)
# 447    0.9  0.1  0.458142  POINT (35.49336064375477 33.89336965439894)
# 448    0.9  0.1  0.384537  POINT (35.49348613839997 33.89336965439894)
# 470    0.9  0.1 -0.063364  POINT (35.49624702059418 33.89336965439894)
# 485    0.9  0.1  0.535423  POINT (35.49348613839997 33.89324415975374)
# 487    0.9  0.1  0.468110  POINT (35.49373712769034 33.89324415975374)
# 488    0.9  0.1  0.456439  POINT (35.49386262233554 33.89324415975374)
# 507    0.9  0.1 -0.056897  POINT (35.49624702059418 33.89324415975374)
# 521    0.9  0.1  0.509633  POINT (35.49336064375477 33.89311866510855)
# 524    0.9  0.1  0.469432  POINT (35.49373712769034 33.89311866510855)
# 544    0.9  0.1 -0.125816  POINT (35.49624702059418 33.89311866510855)
# 547    0.9  0.1  0.010659  POINT (35.49662350452975 33.89311866510855)
# 548    0.9  0.1 -0.054031  POINT (35.49674899917494 33.89311866510855)
# 556    0.9  0.1  0.477744  POINT (35.49310965446439 33.89299317046336)
# 558    0.9  0.1  0.544434  POINT (35.49336064375477 33.89299317046336)
# 559    0.9  0.1  0.598767  POINT (35.49348613839997 33.89299317046336)
# 560    0.9  0.1  0.525747  POINT (35.49361163304516 33.89299317046336)
# 561    0.9  0.1  0.502866  POINT (35.49373712769034 33.89299317046336)
# 593    0.9  0.1  0.324814  POINT (35.49310965446439 33.89286767581817)
# 598    0.9  0.1  0.520910  POINT (35.49373712769034 33.89286767581817)
# 599    0.9  0.1  0.529608  POINT (35.49386262233554 33.89286767581817)
# 619    0.9  0.1 -0.077948  POINT (35.49637251523936 33.89286767581817)
# 620    0.9  0.1 -0.070710  POINT (35.49649800988456 33.89286767581817)
# 621    0.9  0.1 -0.008045  POINT (35.49662350452975 33.89286767581817)
# 633    0.9  0.1  0.432965  POINT (35.49348613839997 33.89274218117298)
# 636    0.9  0.1  0.567945  POINT (35.49386262233554 33.89274218117298)
# 647    0.9  0.1  0.356206  POINT (35.49524306343265 33.89274218117298)
# 656    0.9  0.1 -0.061701  POINT (35.49637251523936 33.89274218117298)
# 657    0.9  0.1 -0.065494  POINT (35.49649800988456 33.89274218117298)
# 669    0.9  0.1  0.313198  POINT (35.49336064375477 33.89261668652779)
# 670    0.9  0.1  0.458468  POINT (35.49348613839997 33.89261668652779)
# 684    0.9  0.1  0.322202  POINT (35.49524306343265 33.89261668652779)
# 685    0.9  0.1  0.333965  POINT (35.49536855807784 33.89261668652779)
# 707    0.9  0.1  0.425322   POINT (35.49348613839997 33.8924911918826)
# 711    0.9  0.1  0.417778   POINT (35.49398811698073 33.8924911918826)
# 781    0.9  0.1  0.372785  POINT (35.49348613839997 33.89224020259221)
# 785    0.9  0.1  0.365560  POINT (35.49398811698073 33.89224020259221)
# 786    0.9  0.1  0.409867  POINT (35.49411361162592 33.89224020259221)
# 814    0.9  0.1  0.408628   POINT (35.4929841598192 33.89211470794702)
#
#      index_right                            decision
# 51       11773.0  GREEN (inspected) أخضر (تم دراسته)
# 108       1687.0  GREEN (inspected) أخضر (تم دراسته)
# 145       1687.0  GREEN (inspected) أخضر (تم دراسته)
# 277      11724.0  GREEN (inspected) أخضر (تم دراسته)
# 279       7983.0  GREEN (inspected) أخضر (تم دراسته)
# 316       7983.0  GREEN (inspected) أخضر (تم دراسته)
# 325       7990.0  GREEN (inspected) أخضر (تم دراسته)
# 326       7990.0  GREEN (inspected) أخضر (تم دراسته)
# 344       7415.0  GREEN (inspected) أخضر (تم دراسته)
# 345       7415.0  GREEN (inspected) أخضر (تم دراسته)
# 346       7415.0  GREEN (inspected) أخضر (تم دراسته)
# 361       7987.0  GREEN (inspected) أخضر (تم دراسته)
# 362       7987.0  GREEN (inspected) أخضر (تم دراسته)
# 374       6494.0  GREEN (inspected) أخضر (تم دراسته)
# 375       6494.0  GREEN (inspected) أخضر (تم دراسته)
# 382       7415.0  GREEN (inspected) أخضر (تم دراسته)
# 393       1441.0  GREEN (inspected) أخضر (تم دراسته)
# 394       1441.0  GREEN (inspected) أخضر (تم دراسته)
# 447       6498.0  GREEN (inspected) أخضر (تم دراسته)
# 448       6498.0  GREEN (inspected) أخضر (تم دراسته)
# 470       4765.0  GREEN (inspected) أخضر (تم دراسته)
# 485       6498.0  GREEN (inspected) أخضر (تم دراسته)
# 487       6501.0  GREEN (inspected) أخضر (تم دراسته)
# 488       6501.0  GREEN (inspected) أخضر (تم دراسته)
# 507       4765.0  GREEN (inspected) أخضر (تم دراسته)
# 521       6351.0  GREEN (inspected) أخضر (تم دراسته)
# 524       6501.0  GREEN (inspected) أخضر (تم دراسته)
# 544       4765.0  GREEN (inspected) أخضر (تم دراسته)
# 547      13778.0  GREEN (inspected) أخضر (تم دراسته)
# 548      13778.0  GREEN (inspected) أخضر (تم دراسته)
# 556       6410.0  GREEN (inspected) أخضر (تم دراسته)
# 558       6351.0  GREEN (inspected) أخضر (تم دراسته)
# 559       6351.0  GREEN (inspected) أخضر (تم دراسته)
# 560       6354.0  GREEN (inspected) أخضر (تم دراسته)
# 561       6354.0  GREEN (inspected) أخضر (تم دراسته)
# 593       6410.0  GREEN (inspected) أخضر (تم دراسته)
# 598       6416.0  GREEN (inspected) أخضر (تم دراسته)
# 599       6416.0  GREEN (inspected) أخضر (تم دراسته)
# 619       4764.0  GREEN (inspected) أخضر (تم دراسته)
# 620       4764.0  GREEN (inspected) أخضر (تم دراسته)
# 621       4764.0  GREEN (inspected) أخضر (تم دراسته)
# 633       6414.0  GREEN (inspected) أخضر (تم دراسته)
# 636       6416.0  GREEN (inspected) أخضر (تم دراسته)
# 647       4761.0  GREEN (inspected) أخضر (تم دراسته)
# 656       4764.0  GREEN (inspected) أخضر (تم دراسته)
# 657       4764.0  GREEN (inspected) أخضر (تم دراسته)
# 669       6412.0  GREEN (inspected) أخضر (تم دراسته)
# 670       6413.0  GREEN (inspected) أخضر (تم دراسته)
# 684       4761.0  GREEN (inspected) أخضر (تم دراسته)
# 685       4761.0  GREEN (inspected) أخضر (تم دراسته)
# 707       6413.0  GREEN (inspected) أخضر (تم دراسته)
# 711       6653.0  GREEN (inspected) أخضر (تم دراسته)
# 781       6402.0  GREEN (inspected) أخضر (تم دراسته)
# 785       6651.0  GREEN (inspected) أخضر (تم دراسته)
# 786       6651.0  GREEN (inspected) أخضر (تم دراسته)
# 814       6349.0  GREEN (inspected) أخضر (تم دراسته)

# %% [markdown]
# _______________
# ## 5 - Create edges

# %%
adjacent = False
ifgValues = True

# %%
edges = []
# Create edges between geographically adjacent nodes
if adjacent:
    x, l = len(df), len(nodes)
    for i in nodes.index:
        if not i % x == x-1: edges.append([i,i+1]) # Pixel to right (edge to left is equivalent to previous edge to right)
        if not i > l-x-1: edges.append([i,i+x]) # Pixel below (edge above is accounted for is equivalent to previous edge below)

# Create edges between most similar phase change pixels
if ifgValues:
    srt = nodes.sort_values(['ifg'])
    for i in range(len(srt.index)-1):
        edges.append([srt.index[i],srt.index[i+1]])

# %% [markdown]
# ____________
# ## 6 - Run NetConf for belief propagation

# %%
# Map for beliefs prior
prePlot = nodes.plot(column='dmg', cmap='RdYlGn_r', legend=True)
prePlot.set_title('A priori damage probability')
# Out:
# Text(0.5, 1.0, 'A priori damage probability')

# %%
priors = np.array(nodes[['noDmg','dmg']])
beliefs, _ = nc.netconf(np.array(edges),priors,verbose=True)
if not os.path.exists('./results'): os.mkdir('results')
np.savetxt('results/BeirutBeliefs.csv', beliefs, delimiter=",", fmt='%s')
print('Output written results/BeirutBeliefs.csv\n')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-12044f5689cc> in <module>
#       1 priors = np.array(nodes[['noDmg','dmg']])
# ----> 2 beliefs, _ = nc.netconf(np.array(edges),priors,verbose=True)
#       3 if not os.path.exists('./results'): os.mkdir('results')
#       4 np.savetxt('results/BeirutBeliefs.csv', beliefs, delimiter=",", fmt='%s')
#       5 print('Output written results/BeirutBeliefs.csv\n')
#
# ~/damage-assessment/netconf/netconf.py in netconf(edges, priors, mod, ep, stop, verbose, max_iter, limit)
#      38   l, diff1 = np.zeros(N), 1
#      39   adj_mat = edges_to_adjmat(edges)
# ---> 40   v, D = np.abs(np.linalg.eigvals(adj_mat))[0], np.diag(sum(adj_mat))
#      41   M = np.dot(np.divide(ep,v),mod)
#      42   M1 = np.dot(M,np.linalg.pinv(np.eye(k)-np.dot(M,M)))
#
# <__array_function__ internals> in eigvals(*args, **kwargs)
#
# /opt/conda/lib/python3.7/site-packages/numpy/linalg/linalg.py in eigvals(a)
#    1052         _raise_linalgerror_eigenvalues_nonconvergence)
#    1053     signature = 'D->D' if isComplexType(t) else 'd->D'
# -> 1054     w = _umath_linalg.eigvals(a, signature=signature, extobj=extobj)
#    1055
#    1056     if not isComplexType(t):
#
# KeyboardInterrupt:

# %%
fig, (ax1, ax2) = plt.subplots(figsize=(15,10), ncols=2, sharex=True, sharey=True)
prePlot = nodes.plot(ax=ax1, column='dmg', cmap='RdYlGn_r', legend=True)
postPlot = nodes.plot(ax=ax2, column=beliefs[:,1], cmap='RdYlGn_r', legend=True)
prePlot.set_title('A priori damage likelihood')
postPlot.set_title('Updated damage likelihood')
# Out:
# Text(0.5, 1.0, 'Updated damage likelihood')

# %% [markdown]
# ___________
# ## Run for multiple edge types at once

# %%
# For multiple runs for different edge options
m = 0
for edgeTypes in ([True, False], [False, True], [True, True]):
    globals()['edges'+str(m)] = []
    adjacent, ifgValues = edgeTypes
    # Create edges between geographically adjacent nodes
    if adjacent:
        x, l = len(df), len(nodes)
        for i in nodes.index:
            if not i % x == x-1: globals()['edges'+str(m)].append([i,i+1]) # Pixel to right (edge to left is equivalent to previous edge to right)
            if not i > l-x-1: globals()['edges'+str(m)].append([i,i+x]) # Pixel below (edge above is accounted for is equivalent to previous edge below)

    # Create edges between most similar phase change pixels
    if ifgValues:
        srt = nodes.sort_values(['ifg'])
        dist = 2
        for i in range(len(srt.index)-dist):
            for j in range(dist-1):
                globals()['edges'+str(m)].append([srt.index[i],srt.index[i+1+j]])
            
    m+=1

# %%
# For multiple edge types
priors = np.array(nodes[['noDmg','dmg']])
for m in range(3): 
    globals()['beliefs'+str(m)], _ = nc.netconf(np.array(globals()['edges'+str(m)]),priors)
# Out:
# 18  iterations
# 18  iterations
# 11  iterations

# %%
# For multiple edge types
fig, axs = plt.subplots(2, 2, figsize=(15,10), sharex=True, sharey=True)
prePlot = nodes.plot(ax=axs[0,0], column='dmg', cmap='RdYlGn_r', legend=True)
postPlot = nodes.plot(ax=axs[0,1], column=beliefs0[:,1], cmap='RdYlGn_r', legend=True)
ifgPlot = nodes.plot(ax=axs[1,0], column=beliefs1[:,1], cmap='RdYlGn_r', legend=True)
comboPlot = nodes.plot(ax=axs[1,1], column=beliefs2[:,1], cmap='RdYlGn_r', legend=True)
prePlot.set_title('A priori damage likelihood')
postPlot.set_title('Geographic edges posterior')
ifgPlot.set_title('Interferogram value edges posterior')
comboPlot.set_title('Combination edges posterior')
# Out:
# Text(0.5, 1.0, 'Combination edges posterior')
