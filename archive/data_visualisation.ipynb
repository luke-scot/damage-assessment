# %% [markdown]
# # Data Visualisation
# This notebook shows visualisations of the various data sources used in this project.
#
# ### Contents
# - 1 - [Building footprints (OSM)](#buildingFootprints)
# - 2 - [Beirut Damage Assessments](#damageAssessment)
#     - [GeoPal](#GeoPal)
#     - [Beirut Recovery Map](#recoveryMap)
# - 3 - [Satellite Imagery](#satelliteImagery)
#     - [Sentinel-2](#sentinel2)
#     - [Sentinel-1](#sentinel1)
#     - [High resolution](#highResolution)
# - 4 - [Ground Imagery](#groundImagery)
#     - [SARAID Photos](#geopalImagery)
#     - [Mapillary](#mapillary)
#
# ### Initialisation

# %%
# Install packages
#%pip install ee geemap

# Package imports
import math
import json
import requests
import os
#import ee
#import geemap
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from tqdm import tqdm
from ipyleaflet import Map, basemaps, GeoData, CircleMarker, Popup, GeoJSON, LegendControl
from ipywidgets import HTML
from IPython.display import Image, display 

import descarteslabs.workflows as wf

# %%
# Define variables
# Location variables
lat, lon, zoom = 33.8975, 35.5063, 14 # Map properties

# Building Footprints variables
buildings = "./data/beirutBuildingFootprints.geojson"

# Damage Assessment variables
dataFile = "./data/geopalData.csv" # GeoPal data
bourjFile = "./data/bourjHammoud.csv"
surveyFile = "./data/SurveyForms.csv"
manualDataFile = "./data/manualDamageClasses.csv"

# Mapillary variables
client_id = 'aGY1d1ZSNFRieTZjempuMHFZc0V6UDowOGE5ODEyZDc0OGJlNzUw' 
bbox = '35.46103477478027,33.87754177691478,35.544376373291016,33.91366258523751'
m_st_date, m_end_date = ['2019-01-01','2020-08-05'],['2020-08-03','2020-12-31']
mapillaryPath = './data/beirutMapillary'

# %% [markdown]
# __________________
# <a id='buildingFootprints'></a>
# ## 1 - Building Footprints
#
# Data outlining Building footprints of Beirut. With a Geojson exported from [OSM](https://www.openstreetmap.org/#map=15/33.8994/35.5006), here we plot the data on a map and then display the header of the database to visualise the information it contains.

# %%
# Plot on map
m1 = Map(basemap=basemaps.OpenStreetMap.Mapnik, center=[lat, lon], zoom=zoom, scroll_wheel_zoom=True)
with open(buildings, 'r') as f: bfs = json.load(f)
geo_json = GeoJSON(data=bfs,
                   style={'opacity': 1, 'dashArray': '9', 'fillOpacity': 0.5, 'weight': 1},
                   hover_style={'color': 'red', 'dashArray': '0', 'fillOpacity': 0.5})

m1.add_layer(geo_json)

display(m1)
m1.save('./data/footprintsMap.html',title='Beirut Building Footprints') # Save map for quick interaction in HTML
# Out:
# Map(center=[33.8975, 35.5063], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zo…

# %%
# Display header 
a = gpd.read_file(buildings)
pd.set_option('display.max_columns', None)
a.head()
# Out:
#                  id               @id     building          type  \
# 0    relation/71853    relation/71853          yes  multipolygon
# 1  relation/6678216  relation/6678216  residential  multipolygon
# 2  relation/6996546  relation/6996546       school  multipolygon
# 3  relation/7000797  relation/7000797       school  multipolygon
# 4  relation/7026674  relation/7026674          yes  multipolygon
#
#                          name addr:city            name:ar  \
# 0                        None      None               None
# 1                        None      None               None
# 2  Collège des Trois Docteurs      None               None
# 3           كلية القلب الأقدس     بيروت  كلية القلب الأقدس
# 4                        None      None               None
#
#                        name:en                name:fr addr:street alt_name  \
# 0                         None                   None        None     None
# 1                         None                   None        None     None
# 2                         None                   None        None     None
# 3  Sacré Cœur Church & Collège  Collège du Sacré-Cœur        None     None
# 4                         None                   None        None     None
#
#   construction_date historic old_name wikidata wikipedia website  \
# 0              None     None     None     None      None    None
# 1              None     None     None     None      None    None
# 2              None     None     None     None      None    None
# 3              None     None     None     None      None    None
# 4              None     None     None     None      None    None
#
#   building:levels amenity tourism fixme layer opening_hours  shop  \
# 0            None    None    None  None  None          None  None
# 1            None    None    None  None  None          None  None
# 2            None    None    None  None  None          None  None
# 3            None    None    None  None  None          None  None
# 4            None    None    None  None  None          None  None
#
#   internet_access stars addr:housenumber addr:postcode government office  \
# 0            None  None             None          None       None   None
# 1            None  None             None          None       None   None
# 2            None  None             None          None       None   None
# 3            None  None             None          None       None   None
# 4            None  None             None          None       None   None
#
#   denomination religion wheelchair created_by name:de name:es  note  \
# 0         None     None       None       None    None    None  None
# 1         None     None       None       None    None    None  None
# 2         None     None       None       None    None    None  None
# 3         None     None       None       None    None    None  None
# 4         None     None       None       None    None    None  None
#
#   addr:city:ar addr:place addr:place:ar height   url contact:phone healthcare  \
# 0         None       None          None   None  None          None       None
# 1         None       None          None   None  None          None       None
# 2         None       None          None   None  None          None       None
# 3         None       None          None   None  None          None       None
# 4         None       None          None   None  None          None       None
#
#   man_made addr:country operator addr:housename country diplomatic embassy  \
# 0     None         None     None           None    None       None    None
# 1     None         None     None           None    None       None    None
# 2     None         None     None           None    None       None    None
# 3     None         None     None           None    None       None    None
# 4     None         None     None           None    None       None    None
#
#   target cuisine source parking phone contact:email contact:facebook  \
# 0   None    None   None    None  None          None             None
# 1   None    None   None    None  None          None             None
# 2   None    None   None    None  None          None             None
# 3   None    None   None    None  None          None             None
# 4   None    None   None    None  None          None             None
#
#   contact:fax contact:website rooms brand brand:ar brand:en brand:wikidata  \
# 0        None            None  None  None     None     None           None
# 1        None            None  None  None     None     None           None
# 2        None            None  None  None     None     None           None
# 3        None            None  None  None     None     None           None
# 4        None            None  None  None     None     None           None
#
#   brand:wikipedia takeaway diplomatic:services:citizen_services  \
# 0            None     None                                 None
# 1            None     None                                 None
# 2            None     None                                 None
# 3            None     None                                 None
# 4            None     None                                 None
#
#   diplomatic:services:immigrant_visas diplomatic:services:non-immigrant_visas  \
# 0                                None                                    None
# 1                                None                                    None
# 2                                None                                    None
# 3                                None                                    None
# 4                                None                                    None
#
#   name:he craft addr:street:ar brand:wikipedia:ar alt_name:ar brand:ru  \
# 0    None  None           None               None        None     None
# 1    None  None           None               None        None     None
# 2    None  None           None               None        None     None
# 3    None  None           None               None        None     None
# 4    None  None           None               None        None     None
#
#   name:ru email   fax leisure contact:mobile construction building:part  \
# 0    None  None  None    None           None         None          None
# 1    None  None  None    None           None         None          None
# 2    None  None  None    None           None         None          None
# 3    None  None  None    None           None         None          None
# 4    None  None  None    None           None         None          None
#
#   start_date level monument ruins   atm disused:railway   fee  \
# 0       None  None     None  None  None            None  None
# 1       None  None     None  None  None            None  None
# 2       None  None     None  None  None            None  None
# 3       None  None     None  None  None            None  None
# 4       None  None     None  None  None            None  None
#
#   internet_access:fee smoking roof:shape name:hy  area barrier name_1 name_2  \
# 0                None    None       None    None  None    None   None   None
# 1                None    None       None    None  None    None   None   None
# 2                None    None       None    None  None    None   None   None
# 3                None    None       None    None  None    None   None   None
# 4                None    None       None    None  None    None   None   None
#
#   tower:type contact:instagram contact:twitter payment:american_express  \
# 0       None              None            None                     None
# 1       None              None            None                     None
# 2       None              None            None                     None
# 3       None              None            None                     None
# 4       None              None            None                     None
#
#   payment:cash payment:cheque payment:credit_cards payment:diners_club  \
# 0         None           None                 None                None
# 1         None           None                 None                None
# 2         None           None                 None                None
# 3         None           None                 None                None
# 4         None           None                 None                None
#
#   payment:mastercard payment:visa architect addr:city:arc addr:city:syc  \
# 0               None         None      None          None          None
# 1               None         None      None          None          None
# 2               None         None      None          None          None
# 3               None         None      None          None          None
# 4               None         None      None          None          None
#
#   emergency description historic:civilization name:zh landuse military  \
# 0      None        None                  None    None    None     None
# 1      None        None                  None    None    None     None
# 2      None        None                  None    None    None     None
# 3      None        None                  None    None    None     None
# 4      None        None                  None    None    None     None
#
#   fuel:octane_95 fuel:octane_98 delivery studio alt_name:en   ele  \
# 0           None           None     None   None        None  None
# 1           None           None     None   None        None  None
# 2           None           None     None   None        None  None
# 3           None           None     None   None        None  None
# 4           None           None     None   None        None  None
#
#   internet_access:ssid addr:street:en healthcare:speciality operator:type  \
# 0                 None           None                  None          None
# 1                 None           None                  None          None
# 2                 None           None                  None          None
# 3                 None           None                  None          None
# 4                 None           None                  None          None
#
#   name_alt long_name:ar addr:building addr:building:fr addr:city:fr  \
# 0     None         None          None             None         None
# 1     None         None          None             None         None
# 2     None         None          None             None         None
# 3     None         None          None             None         None
# 4     None         None          None             None         None
#
#   addr:street:fr outdoor_seating castle_type sport   bus network  \
# 0           None            None        None  None  None    None
# 1           None            None        None  None  None    None
# 2           None            None        None  None  None    None
# 3           None            None        None  None  None    None
# 4           None            None        None  None  None    None
#
#   public_transport access entrance supervised payment:debit_cards dispensing  \
# 0             None   None     None       None                None       None
# 1             None   None     None       None                None       None
# 2             None   None     None       None                None       None
# 3             None   None     None       None                None       None
# 4             None   None     None       None                None       None
#
#   clothes image diet:meat opening_hours:covid19 @relations bicycle  foot  \
# 0    None  None      None                  None       None    None  None
# 1    None  None      None                  None       None    None  None
# 2    None  None      None                  None       None    None  None
# 3    None  None      None                  None       None    None  None
# 4    None  None      None                  None       None    None  None
#
#   motor_vehicle highway crossing artwork_type artist_name  \
# 0          None    None     None         None        None
# 1          None    None     None         None        None
# 2          None    None     None         None        None
# 3          None    None     None         None        None
# 4          None    None     None         None        None
#
#                                             geometry
# 0  POLYGON ((35.4894536 33.8946995, 35.4894132 33...
# 1  POLYGON ((35.524633 33.8898401, 35.5246194 33....
# 2  POLYGON ((35.5185524 33.8949802, 35.5185834 33...
# 3  (POLYGON ((35.5106324 33.895221, 35.5106476 33...
# 4  POLYGON ((35.5053153 33.893788, 35.5048335 33....

# %% [markdown]
# The map, despite the slightly laggy display due to quantity of data, shows that OSM has excellent building footprint coverage in Beirut. One issue may be the lack of a date on the footprints especiually considering the August 2020 explosion. The table shows that very varied information exists for some buldings but the data is sparse within the detail columns.
# - Advantages: Coverage, detailed building outlines, extra building details, freely available
# - Limitations: No dates, details sparse for most entries
# __________________
# <a id='damageAssessment'></a>
# ## 2 - Beirut Damage Assessment
# Data gathered during the damage assessment of the Beirut explosion.
# <a id='GeoPal'></a>
# ### GeoPal
# Here we have extracted all the damage assessment information gathered by [SARAID](https://www.saraid.org/) that is accessible through GeoPal. We'll first take a look at the data, then narrow this down to the useful components and finally have a look at spatial distribution.

# %%
# View first 5 rows of whole GeoPal data
allData = pd.read_csv(dataFile)
bourj = pd.read_csv(bourjFile)
survey = pd.read_csv(surveyFile)
manual = pd.read_csv(manualDataFile)
pd.set_option('display.max_columns', None) # Show all columns
allData.head()
# Out:
#   Job ID                    Job Name         Created By        Created On  \
# 0    278  Building Assessment Beirut  Christel Bercachy  11/08/2020 17:54
# 1    279  Building Assessment Beirut  Christel Bercachy  11/08/2020 17:57
# 2    280  Building Assessment Beirut  Christel Bercachy  11/08/2020 18:00
# 3    281  Building Assessment Beirut  Christel Bercachy  11/08/2020 18:06
# 4    282  Building Assessment Beirut  Christel Bercachy  11/08/2020 18:10
#
#   Assigned To Assigned Date Time Preferred Start        Preferred End  \
# 0         NaN                NaN             NaN  0000-00-00 00:00:00
# 1         NaN                NaN             NaN  0000-00-00 00:00:00
# 2         NaN                NaN             NaN  0000-00-00 00:00:00
# 3         NaN                NaN             NaN  0000-00-00 00:00:00
# 4         NaN                NaN             NaN  0000-00-00 00:00:00
#
#    Contact Id  First Name  Last Name Address Line 1 Address Line 2  \
# 0         NaN         NaN        NaN            NaN            NaN
# 1         NaN         NaN        NaN            NaN            NaN
# 2         NaN         NaN        NaN            NaN            NaN
# 3         NaN         NaN        NaN            NaN            NaN
# 4         NaN         NaN        NaN            NaN            NaN
#
#   Address Line 3 City  Postal Code  Contact Phone Number  \
# 0            NaN  NaN          NaN                   NaN
# 1            NaN  NaN          NaN                   NaN
# 2            NaN  NaN          NaN                   NaN
# 3            NaN  NaN          NaN                   NaN
# 4            NaN  NaN          NaN                   NaN
#
#    Contact Mobile Number  Contact Email  Company Id  Company Name  \
# 0                    NaN            NaN         NaN           NaN
# 1                    NaN            NaN         NaN           NaN
# 2                    NaN            NaN         NaN           NaN
# 3                    NaN            NaN         NaN           NaN
# 4                    NaN            NaN         NaN           NaN
#
#          Start Time End Time Last Updated Date Time         Status Notes  \
# 0  11/08/2020 17:54      NaN       17/08/2020 11:24  JOB_CANCELLED   NaN
# 1  12/08/2020 14:24      NaN       24/08/2020 08:02  JOB_COMPLETED   NaN
# 2  11/08/2020 17:59      NaN       17/08/2020 11:21  JOB_CANCELLED   NaN
# 3  11/08/2020 18:06      NaN       17/08/2020 11:20  JOB_CANCELLED   NaN
# 4  11/08/2020 18:10      NaN       17/08/2020 11:19  JOB_CANCELLED   NaN
#
#   check in - بدء_w_2049197 get location - الموقع_w_2049198  \
# 0         11/08/2020 17:54           33.8830089 35.5577379
# 1         12/08/2020 14:24                             NaN
# 2         11/08/2020 17:59           33.8830024 35.5577550
# 3         11/08/2020 18:06           33.8830063 35.5577587
# 4         11/08/2020 18:10                             NaN
#
#   point on map - الموقع على الخريطة_w_2049199  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   plot number - رقم العقار_w_2049200 plot area - المنطقة العقارية_w_2049201  \
# 0                                123                   El Bachoura الباشورة
# 1                               Test                   El Bachoura الباشورة
# 2                                123                     Achrafieh الأشرفية
# 3                                123                     Achrafieh الأشرفية
# 4                                 23                       El Marfaa المرفأ
#
#   street - الشارع_w_2049203 building status - وضع البناء_w_2049204  \
# 0                       NaN                                    NaN
# 1                       NaN                                    NaN
# 2                       NaN          Opened on 2020-08-12 10:40:12
# 3                 Achrafieh          Opened on 2020-08-11 20:07:31
# 4                       NaN                                    NaN
#
#   structural damage level - مستوى الضرر الأنشائي للمبنى_w_2049205  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Partially destroyed (poses a public safety haz...
# 4                                                NaN
#
#   must be evacuated? - هل يتوجب إخلاؤه؟_w_2049206  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                         Yes نعم
# 4                                             NaN
#
#   evacuation note - ملاحظة عن ضرورة الإخلاء_w_2049207  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    number of floors - عدد الطوابق_w_2049208  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       5.0
# 4                                       NaN
#
#    number of units - عدد الشقق_w_2049209  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    5.0
# 4                                    NaN
#
#   building use - وجهة الاستعمال للمبنى_w_2049210  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3              Residential سكني,Commercial تجاري
# 4                                            NaN
#
#   ground floor use - وجهة الاستعمال للطابق الأرضي_w_2049211  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                   Commercial تجاري
# 4                                                NaN
#
#   affected facades - واجهات البناء المتضررة_w_2049212  \
# 0                                                NaN
# 1                                                NaN
# 2                      Opened on 2020-08-12 10:40:15
# 3                      Opened on 2020-08-11 20:08:33
# 4                                                NaN
#
#   glass sqm (approximate quantity) - الكمية التقريبية للزجاج_w_2049213  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   glass and aluminum sqm (approximate quantity)  - الكمية التقريبية للألمنيوم و الزجاج_w_2049214  \
# 0                                                NaN
# 1                                                NaN
# 2                                                 62
# 3                                                NaN
# 4                                                NaN
#
#    sliding doors sqm  (approximate quantity)  - الكمية التقريبية للأبواب الجرارة_w_2049215  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    balconies sqm (approximate quantity)  - الكمية التقريبية للشرفات_w_2049216  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    cladding sqm (approximate quantity)  -الكمية التقريبية للتلبيس_w_2049217  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                               74.0
# 4                                                NaN
#
#    external walls sqm (approximate quantity)  - الكمية التقريبية للجدران الخارجية_w_2049218  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    brick pitched roof sqm (approximate quantity)  - الكمية التقريبية لتكنة قرميد_w_2049219  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   others (approximate quantity)  - الكمية التقريبية للواجهات الأخرى_w_2049220  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   heritage building - مبنى تراثي_w_2049221  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                   No كلا
# 4                                      NaN
#
#                 take pictures - التقاط صور_w_2049222 upload photo_w_2049684  \
# 0  https://app.geopalsolutions.com/jobs/viewworkf...                    NaN
# 1  https://app.geopalsolutions.com/jobs/viewworkf...                    NaN
# 2  https://app.geopalsolutions.com/jobs/viewworkf...                    NaN
# 3                                                NaN                    NaN
# 4                                                NaN                    NaN
#
#   manual report picture_w_2049685 other notes - ملاحظات أخرى_w_2049223  \
# 0                             NaN                                  NaN
# 1                             NaN                                  NaN
# 2                             NaN                                  NaN
# 3                             NaN                                  NaN
# 4                             NaN                                  NaN
#
#   decision - القرار_w_2049224 describe restrictions - وصف القيود_w_2049225  \
# 0                         NaN                                          NaN
# 1                         NaN                                          NaN
# 2                         NaN                                          NaN
# 3                         NaN                                          NaN
# 4                         NaN                                          NaN
#
#   disclaimer_w_2051714 check out - إنهاء_w_2049226  Asset Identifier  \
# 0                  NaN                         NaN               NaN
# 1                  NaN                         NaN               NaN
# 2                  NaN                         NaN               NaN
# 3                  NaN                         NaN               NaN
# 4                  NaN                         NaN               NaN
#
#    Asset Name  Asset Type  Teams  Sites Time Working Time Paused Time Active  \
# 0         NaN         NaN    NaN    NaN     00:00:00    00:00:00    00:00:00
# 1         NaN         NaN    NaN    NaN     00:00:00    00:00:00    00:00:00
# 2         NaN         NaN    NaN    NaN     00:00:00    00:00:00    00:00:00
# 3         NaN         NaN    NaN    NaN     00:00:00    00:00:00    00:00:00
# 4         NaN         NaN    NaN    NaN     00:00:00    00:00:00    00:00:00
#
#    Project Identifier  Project Name Completed And Synced Date Time
# 0                 NaN           NaN                            NaN
# 1                 NaN           NaN                            NaN
# 2                 NaN           NaN                            NaN
# 3                 NaN           NaN                            NaN
# 4                 NaN           NaN                            NaN

# %%
# Extract useful information
# Extract locations from joint column in database 
def get_coords(locations, mapPoints):
    lats, lons = np.zeros([len(locations), 1]),  np.zeros([len(locations), 1])
    for i in range(len(locations)):
        loc = locations[i]
        if type(loc) is float or (type(loc) is str and loc[0].isalpha()):
            mp = mapPoints[i]
            if type(mp) is str and mp[0].isdigit():
                try: lats[i], lons[i] = mp.split(' ')[0], mp.split(' ')[1]
                except: lats[i], lons[i] = mp.split(',')[0], mp.split(',')[1] # Deal with rogue commas instead of space
        else: lats[i], lons[i] = loc.split(' ')[0], loc.split(' ')[1]
    return lats, lons

lats, lons = get_coords(allData['get location - الموقع_w_2049198'], allData['point on map - الموقع على الخريطة_w_2049199'])
# Extract columns of useful data
dataBeirut = pd.DataFrame({
    'id': allData['Job ID'],
    'area': allData['plot area - المنطقة العقارية_w_2049201'],
    'damage': allData['structural damage level - مستوى الضرر الأنشائي للمبنى_w_2049205'],
    'floors': allData['number of floors - عدد الطوابق_w_2049208'],
    'units': allData['number of units - عدد الشقق_w_2049209'],
    'use': allData['building use - وجهة الاستعمال للمبنى_w_2049210'],
    'photos': allData['take pictures - التقاط صور_w_2049222'],
    'decision': allData['decision - القرار_w_2049224']    
})

# Create geodatabase merging locations with useful data
assBeirut = gpd.GeoDataFrame(dataBeirut, geometry=gpd.points_from_xy(lons, lats))

lats, lons = get_coords(bourj['get location - الموقع_w_2048240'], bourj['point on map - الموقع على الخريطة_w_2048241'])
dataBourj = pd.DataFrame({
    'id': bourj['Job ID'],
    'area': bourj['plot area - المنطقة العقارية_w_2048243'],
    'damage': bourj['damage level - مستوى الضرر_w_2048246'],
    'floors': bourj['number of floors - عدد اطوابق_w_2048249'],
    'units': bourj['number of units - عدد الشقق_w_2048250'],
    'use': bourj['building use - وجهة الاستعمال للمبنى_w_2048409'],
    'photos': bourj['take pictures - التقاط صور_w_2048261'],
    'decision': bourj['decision - القرار_w_2048411']    
})
assBourj = gpd.GeoDataFrame(dataBourj, geometry=gpd.points_from_xy(lons, lats))

assessments2 = assBeirut.append(assBourj, ignore_index=True)
assessments =  assessments2.append(gpd.GeoDataFrame(manual['decision'], geometry=gpd.points_from_xy(manual['Lon'], manual['Lat'])), ignore_index=True)

located = assessments[assessments.geometry.x != 0]
located
# Out:
#         id                  area  \
# 0      278  El Bachoura الباشورة
# 2      280    Achrafieh الأشرفية
# 3      281    Achrafieh الأشرفية
# 5      283    Achrafieh الأشرفية
# 6      284    Achrafieh الأشرفية
# ...    ...                   ...
# 11188  NaN                   NaN
# 11189  NaN                   NaN
# 11190  NaN                   NaN
# 11191  NaN                   NaN
# 11192  NaN                   NaN
#
#                                                   damage  floors  units  \
# 0                                                    NaN     NaN    NaN
# 2                                                    NaN     NaN    NaN
# 3      Partially destroyed (poses a public safety haz...     5.0    5.0
# 5      Partially destroyed (poses a public safety haz...     4.0    5.0
# 6      Partially destroyed (poses a public safety haz...     4.0    8.0
# ...                                                  ...     ...    ...
# 11188                                                NaN     NaN    NaN
# 11189                                                NaN     NaN    NaN
# 11190                                                NaN     NaN    NaN
# 11191                                                NaN     NaN    NaN
# 11192                                                NaN     NaN    NaN
#
#                                      use  \
# 0                                    NaN
# 2                                    NaN
# 3      Residential سكني,Commercial تجاري
# 5      Residential سكني,Commercial تجاري
# 6      Residential سكني,Commercial تجاري
# ...                                  ...
# 11188                                NaN
# 11189                                NaN
# 11190                                NaN
# 11191                                NaN
# 11192                                NaN
#
#                                                   photos  \
# 0      https://app.geopalsolutions.com/jobs/viewworkf...
# 2      https://app.geopalsolutions.com/jobs/viewworkf...
# 3                                                    NaN
# 5      https://app.geopalsolutions.com/jobs/viewworkf...
# 6      https://app.geopalsolutions.com/jobs/viewworkf...
# ...                                                  ...
# 11188                                                NaN
# 11189                                                NaN
# 11190                                                NaN
# 11191                                                NaN
# 11192                                                NaN
#
#                                            decision  \
# 0                                               NaN
# 2                                               NaN
# 3                                               NaN
# 5      YELLOW (restricted use) أصفر (لا يصلح للسكن)
# 6      YELLOW (restricted use) أصفر (لا يصلح للسكن)
# ...                                             ...
# 11188                                        YELLOW
# 11189                                        YELLOW
# 11190                                        YELLOW
# 11191                                        YELLOW
# 11192                                           RED
#
#                                  geometry
# 0           POINT (35.5577379 33.8830089)
# 2            POINT (35.557755 33.8830024)
# 3           POINT (35.5577587 33.8830063)
# 5           POINT (35.5577435 33.8830157)
# 6           POINT (35.5577312 33.8829998)
# ...                                   ...
# 11188  POINT (35.52849000000001 33.90049)
# 11189            POINT (35.53178 33.9012)
# 11190  POINT (35.53100999999999 33.90117)
# 11191           POINT (35.52803 33.89748)
# 11192  POINT (35.52594000000001 33.89717)
#
# [9727 rows x 9 columns]

# %%
## Plot data on map
# Create Map
m2 = Map(basemap=basemaps.OpenStreetMap.Mapnik, center=[lat, lon], zoom=zoom, scroll_wheel_zoom=True)

# Assign colours according to decision
color_dict = {'GREEN (inspected) أخضر (تم دراسته)': 'green', 'GREEN':'green', 'YELLOW (restricted use) أصفر (لا يصلح للسكن)': 'Yellow', 'YELLOW': 'Yellow', 'RED (unsafe/evacuate) أحمر (غير آمن/للاخلاء)ء': 'red', 'RED':'red', np.nan: 'blue'}
located['color'] = [color_dict[i] for i in located.decision]

# Create marker for each point
for i in tqdm(located.index):
    a = located.loc[i]
    location = (a.geometry.y,a.geometry.x)
    marker = CircleMarker(location=location, radius = 3, color=a.color, fill_color=a.color, fill_opacity=0.8, opacity=0.6)

    # Popup associated to a layer
    msg = HTML()
    if not a.damage is np.nan:
        msg.value = ("Job ID: {}<br>"
                     "Area: {}<br>"
                     "Damage: {}<br>"
                     "Floors: {}<br>"
                     "Units: {}<br>"
                     "Use: {}<br>"
                     "Photos:{}<br>").format(a.id,a.area,a.damage,a.floors,a.units,a.use,' None' if a.photos=='nan' else '<a href='+str(a.photos)+'> Click Link</a>')
    marker.popup = msg
    m2.add_layer(marker)

if not 'l2' in globals(): # Add legend if forming map for first time
    l2 = legend = LegendControl({"No Restrictions":"#008000", "Restricted Use":"#FFFF00", "Unsafe/Evacuated":"#FF0000", "No Decision":"#0000FF"}, name="Decision", position="bottomleft")
    m2.add_control(l2)
    
m2.save('./data/allGeopalMap.html', title='GeoPal Map') # Save map for quick interaction in HTML
m2
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# 100%|██████████| 9727/9727 [09:46<00:00, 16.59it/s]
# Map(center=[33.8975, 35.5063], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zo…

# %% [markdown]
# ## Merge of GeoPal and OSM

# %%
buildingFile = "./data/beirutBuildingFootprints.geojson" # OSM data
assessmentFile = "./data/geopalData.csv" # GeoPal data
bourjData = "./data/bourjHammoud.csv" # GeoPal Extra
manualData = "./data/manualDamageClasses.csv" # GeoPal manual data
crs = 'epsg:4326' # Coordinate system

Import OSM
footprints = ip.import_OSM_fps(buildingFile)

# Import GeoPal assessments
assessments1 = ip.import_located_geopal_data(assessmentFile)
assessments2 = ip.append_geopal_data(assessments1, bourjData, 'decision - القرار_w_2048411', True)
assessments = ip.append_geopal_data(assessments2, manualData)

# Get joint geodataframe of building footprints with damage assessments
labels = hf.join_gdfs(footprints, assessments, column=cn)

# %% [markdown]
# ____________________

# %% [markdown]
# The GeoPal data has an excellent aspect of Green/Yellow/Red classification for damage/safety of buildings which considers both the structural integrity and safety to the population which is exactly what we are looking for in a Search & Rescue application.
# - Advantages: Detailed assessment, G/Y/R classification
# - Limitatins: Coverage both due to non-assessment and 465 unlocated assessments
# <a id='recoveryMap'></a>
# ### Beirut Recovery Map data
# Here we import data used in the Rice University [Beirut Recovery Map](https://beirutrecovery.org/) interactive tool. The data sources are the following:
# - [Beirut FER](https://gis.army.gov.lb/lm/index.php/view/map/?repository=15&project=open) - most complete, we need to request access somehow
# - [NASA ARIA](https://www.jpl.nasa.gov/images/aria-damage-map-beirut-explosion-aftermath) - inferred from Sentinel-1 data, see [Sentinel-1 section](#sentinel1)
# - [Lebanese Red Cross](https://www.redcross.org.lb/) - incomplete
# - Impressive 3D building data - principally based on [Salim Alkadi's model](http://www.salimalkadi.com/07_beirut-001) which can be viewed in [Rhinoceros](https://www.rhino3d.com/) software

# %%
bhSurv = gpd.read_file("data/BH_SurvDigitalGeopComp.shp")
bhSurv.plot()

# %%
bhSurv.columns
# Out:
# Index(['OBJECTID_1', 'OBJECTID', 'Handle', 'Drawn_by', 'OBJECTID_2', 'Layer_1',
#        'RefName_1', 'Text_1', 'ORIG_FID', 'Parcel_Num', 'Job_ID', 'check_in__',
#        'plot_numbe', 'PlotNum', 'building_c', 'damage_lev', 'Charbel_co',
#        'must_be_ev', 'number_of', 'number_o_1', 'building_u', 'ground_flo',
#        'structure', 'decision__', 'check_out', 'Parcel', 'Shape_Leng',
#        'Shape_Area', 'geometry'],
#       dtype='object')

# %%
mob = gpd.read_file("data/Classified_Parcels_MoB_20200907.shp")
survey = gpd.read_file("data/Classified_Parcels_Survey_20200909.shp")
mob.plot()
survey.plot()

# %%
bhSurv['decision'] = bhSurv['decision__']
bhSurv.to_crs("EPSG:32636")[['geometry','decision']].dropna()
# Out:
#                                                geometry  \
# 0     POLYGON Z ((734779.1928255011 3752382.51716927...
# 1     POLYGON Z ((734773.5131084514 3752398.56225095...
# 2     POLYGON Z ((734756.2391538185 3752360.32901136...
# 3     POLYGON Z ((734778.1803394713 3752346.35854667...
# 4     POLYGON Z ((734783.677740526 3752299.363261598...
# ...                                                 ...
# 3809  POLYGON Z ((735409.3142148447 3753300.54358791...
# 3810  POLYGON Z ((735170.3981156985 3753746.09557747...
# 3811  POLYGON Z ((734905.5724976008 3753650.81643763...
# 3812  POLYGON Z ((734886.6727293299 3753580.75659456...
# 3813  POLYGON Z ((735127.8432133498 3753945.80982525...
#
#                                           decision
# 0               GREEN (inspected) أخضر (تم دراسته)
# 1               GREEN (inspected) أخضر (تم دراسته)
# 2               GREEN (inspected) أخضر (تم دراسته)
# 3               GREEN (inspected) أخضر (تم دراسته)
# 4               GREEN (inspected) أخضر (تم دراسته)
# ...                                            ...
# 3809            GREEN (inspected) أخضر (تم دراسته)
# 3810  YELLOW (restricted use) أصفر (لا يصلح للسكن)
# 3811            GREEN (inspected) أخضر (تم دراسته)
# 3812  YELLOW (restricted use) أصفر (لا يصلح للسكن)
# 3813  YELLOW (restricted use) أصفر (لا يصلح للسكن)
#
# [3266 rows x 2 columns]

# %%
# a = mob.to_crs('epsg:4326')
# a.plot()
mob['decision'] = mob['Category']
survey['decision'] = survey['decision__']
bhSurv['decision'] = bhSurv['decision__']

# %%
survey.columns
# Out:
# Index(['OBJECTID', 'PID', 'POINT_X', 'POINT_Y', 'dip', 'Zones', 'Cadaster',
#        'Job_ID', 'Job_Name', 'Created_On', 'Assigned_D', 'Preferred',
#        'Preferre_1', 'Contact_Id', 'First_Name', 'Last_Name', 'Address_Li',
#        'Address__1', 'Address__2', 'City', 'Postal_Cod', 'Contact_Ph',
#        'Contact_Mo', 'Contact_Em', 'Company_Id', 'Company_Na', 'Start_Time',
#        'End_Time', 'Last_Updat', 'Status', 'Notes', 'check_in__', 'get_locati',
#        'point_on_m', 'point_on_1', 'point_on_2', 'plot_numbe', 'plot_num_1',
#        'plot_num_2', 'plot_num_3', 'plot_area', 'street____', 'building_s',
#        'structural', 'must_be_ev', 'evacuation', 'number_of', 'number_o_1',
#        'ground_flo', 'affected_f', 'glass_sqm', 'glass_and', 'sliding_do',
#        'balconies', 'cladding_s', 'external_w', 'brick_pitc', 'others__ap',
#        'take_pictu', 'upload_pho', 'manual_rep', 'other_note', 'decision__',
#        'describe_r', 'disclaimer', 'check_out', 'Asset_Iden', 'Asset_Name',
#        'Asset_Type', 'Teams', 'Sites', 'Time_Worki', 'Time_Pause',
#        'Time_Activ', 'Project_Id', 'Project_Na', 'Completed', 'geometry'],
#       dtype='object')

# %%
gdf = gpd.GeoDataFrame(pd.concat([mob[['decision','geometry']].dropna(), survey[['decision','geometry']].dropna(), bhSurv.to_crs("EPSG:32636")[['geometry','decision']].dropna()], ignore_index=True), crs="epsg:32636").to_crs("EPSG:4326")

# %%
gdf
# Out:
#                                 decision  \
# 0                                  GREEN
# 1                                  GREEN
# 2                                  GREEN
# 3                                 YELLOW
# 4                                  GREEN
# ...                                  ...
# 9182  GREEN (inspected) ???? (?? ??????)
# 9183  GREEN (inspected) ???? (?? ??????)
# 9184  GREEN (inspected) ???? (?? ??????)
# 9185  GREEN (inspected) ???? (?? ??????)
# 9186  GREEN (inspected) ???? (?? ??????)
#
#                                                geometry
# 0     POLYGON Z ((33.88589105811617 35.5053781425190...
# 1     POLYGON Z ((33.88586050921178 35.5056356634317...
# 2     POLYGON Z ((33.88582477613778 35.5054983853419...
# 3     POLYGON Z ((33.88582072992963 35.5057609524688...
# 4     POLYGON Z ((33.88567576998236 35.5057443080062...
# ...                                                 ...
# 9182  POLYGON Z ((33.89935664324458 35.4909584242003...
# 9183  POLYGON Z ((33.89934605933868 35.4912642405035...
# 9184  POLYGON Z ((33.88846463956402 35.4975264811517...
# 9185  POLYGON Z ((33.89314892882407 35.4943838096879...
# 9186  POLYGON Z ((33.88736607263846 35.5105401138214...
#
# [9187 rows x 2 columns]

# %%
mob = gpd.read_file("data/Classified_Parcels_MoB_20200907.shp")
survey = gpd.read_file("data/Classified_Parcels_Survey_20200909.shp")
bhSurv = gpd.read_file("data/BH_SurvDigitalGeopComp.shp")
mob.plot()
survey.plot()
bhSurv.plot()
mob.rename(columns={'Category':'decision'},inplace=True)
survey.rename(columns={'decision__':'decision'},inplace=True)
bhSurv.rename(columns={'decision__':'decision'},inplace=True)

gdf = gpd.GeoDataFrame(pd.concat([mob[['decision','geometry']].dropna(), survey[['decision','geometry']].dropna(), bhSurv.to_crs("EPSG:32636")[['geometry','decision']].dropna()], ignore_index=True), crs="epsg:32636").to_crs({'init':"EPSG:4326"})
gdf['decision'] = gdf.decision.str.split().str.get(0)
gdf.plot()
gdf.to_file("data/allDamages.shp")

# %%
gdf.to_crs("epsg:4326")
# Out:
#      decision                                           geometry
# 0       GREEN  POLYGON Z ((33.88589105811617 35.5053781425190...
# 1       GREEN  POLYGON Z ((33.88586050921178 35.5056356634317...
# 2       GREEN  POLYGON Z ((33.88582477613778 35.5054983853419...
# 3      YELLOW  POLYGON Z ((33.88582072992963 35.5057609524688...
# 4       GREEN  POLYGON Z ((33.88567576998236 35.5057443080062...
# ...       ...                                                ...
# 9182    GREEN  POLYGON Z ((33.89935664324458 35.4909584242003...
# 9183    GREEN  POLYGON Z ((33.89934605933868 35.4912642405035...
# 9184    GREEN  POLYGON Z ((33.88846463956402 35.4975264811517...
# 9185    GREEN  POLYGON Z ((33.89314892882407 35.4943838096879...
# 9186    GREEN  POLYGON Z ((33.88736607263846 35.5105401138214...
#
# [9187 rows x 2 columns]

# %%
convert=gdf.copy()
import shapely.geometry as sg
for i, val in enumerate(convert.geometry):
    if "MultiPolygon" in str(type(val)):
        print(i)
        polys = []
        for p in val:
            polys += [sg.Polygon(list(zip(p.exterior.coords.xy[1], p.exterior.coords.xy[0])))]
            convert.geometry[i] = sg.MultiPolygon(polys)
    else: convert.geometry[i] = sg.Polygon(list(zip(val.exterior.coords.xy[1], val.exterior.coords.xy[0])))
# Out:
# 2862
# 3039
# 3386
# 3441
# 3617
# 5252
# 8777
# 8856

# %%
convert.to_file("data/beirutDamages.shp")

# %%
mob.to_crs("epsg:4326")
# Out:
#       OBJECTID      PID      POINT_X       POINT_Y  dip           Zones  \
# 0         7581   Ba_521  731700.4005  3.752319e+06    0              B4
# 1         7582   Ba_535  731726.8647  3.752320e+06    0              B4
# 2         7583   Ba_533  731715.7777  3.752311e+06    0              B4
# 3         7584   Ba_534  731737.3381  3.752315e+06    0              B4
# 4         7585  Ba_1357  731728.0962  3.752303e+06    0              B4
# ...        ...      ...          ...           ...  ...             ...
# 3428         0  Po_1545       0.0000  0.000000e+00    0    Port seaside
# 3429         0  Mi_1455       0.0000  0.000000e+00    0            None
# 3430         0   Sa_405       0.0000  0.000000e+00    0              S6
# 3431         0   Sa_237       0.0000  0.000000e+00    0              S2
# 3432         0  Mi_1401       0.0000  0.000000e+00    0  Minaa El Hosen
#
#      Cadaster   Parcel Category            Zone       Remark Column1  \
# 0        None   Ba_521    GREEN              B4         None    None
# 1        None   Ba_535    GREEN              B4         None    None
# 2        None   Ba_533    GREEN              B4         None    None
# 3        None   Ba_534   YELLOW              B4         None    None
# 4        None  Ba_1357    GREEN              B4         None    None
# ...       ...      ...      ...             ...          ...     ...
# 3428     None  Po_1545      RED    Port seaside         None    None
# 3429     None  Mi_1455    GREEN  Minaa El Hosen         None    None
# 3430     None   Sa_405    GREEN              S6  Sa_405-1079    None
# 3431     None   Sa_237    GREEN              S2         None    None
# 3432     None  Mi_1401    GREEN  Minaa El Hosen    1401-1422    None
#
#                                                geometry
# 0     POLYGON Z ((33.88589105811617 35.5053781425190...
# 1     POLYGON Z ((33.88586050921178 35.5056356634317...
# 2     POLYGON Z ((33.88582477613778 35.5054983853419...
# 3     POLYGON Z ((33.88582072992963 35.5057609524688...
# 4     POLYGON Z ((33.88567576998236 35.5057443080062...
# ...                                                 ...
# 3428  POLYGON Z ((33.90672856825809 35.5078414298767...
# 3429  POLYGON Z ((33.90412494401837 35.4986067610536...
# 3430  POLYGON Z ((33.89722788508578 35.5096554782576...
# 3431  POLYGON Z ((33.88981988393864 35.5097745857142...
# 3432  POLYGON Z ((33.90087702367062 35.4975105317378...
#
# [3433 rows x 13 columns]

# %% [markdown]
# _____________
# <a id='satelliteImagery'></a>
# ## 3 - Satellite Imagery
# Let's now look at available satellite imagery for before/after the beirut explosion. You'll need the magic markers beneath the maps to scale the images.

# %%
# Define function for retrieving satellite imagery from Descartes platform and displaying on map
def getImage(satellite,bands,st_date,end_date,time,opacity=1,mapNum=m1,cloudFraction=0.1):
    img = wf.ImageCollection.from_id(satellite,start_datetime=st_date[time], end_datetime=end_date[time])
    if 'sentinel-2' in satellite: # Use sentinel cloud-mask band if available
        img = img.filter(lambda img: img.properties["cloud_fraction"] <= cloudFraction)
        img = img.map(lambda img: img.mask(img.pick_bands('cloud-mask')==1))
    mos = (img.mosaic().pick_bands(bands))
    globals()['mos_'+str(time+1)+str(bands)] = mos
    display = mos.visualize('Image '+str(time+1)+str(bands), map=mapNum)
    display.opacity = opacity
    return mos

# %% [markdown]
# <a id='sentinel2'></a>
# ### Sentinel-2

# %%
# Initialise map
m4 = wf.interactive.MapApp()
m4.center, m4.zoom = (lat, lon), zoom

satellite, bands, cloudFraction = "sentinel-2:L1C", ['red','green','blue'], 0.03
st_date, end_date = ['2020-07-24T00:00:00.000Z', '2020-08-18T00:00:00.000Z'], ['2020-07-24T14:00:00.000Z', '2020-08-18T14:00:00.000Z'] # Timeframes for before-after imagery: start 1, start 2; end 1 ,end 2

# Loop over dates (time 1 & time 2)
for i in range(len(st_date)):
    mos = getImage(satellite, bands, st_date, end_date, i, 1, m4, cloudFraction)

m4
# Out:
# `ipyleaflet` and/or `ipywidgets` Jupyter extensions are not installed! (or you're not in a Jupyter notebook.)
# To install for JupyterLab, run this in a cell:
#     !jupyter labextension install jupyter-leaflet @jupyter-widgets/jupyterlab-manager
# To install for plain Jupyter Notebook, run this in a cell:
#     !jupyter nbextension enable --py --sys-prefix ipyleaflet
# Then, restart the kernel and refresh the webpage.

# %%
mos

# %%
type(a)
# Out:
# descarteslabs.workflows.result_types.types.ImageResult

# %%
import descarteslabs as dl
raster_client = dl.Raster()
raster_client.raster(
    inputs=a,
    bands=["red", "green", "blue"],
    #scales=[[0, 5500], [0, 5500], [0, 5500], None],
    data_type="Byte",
    cutline=box,
    save=True,
    outfile_basename="save_local",
    resolution=10,
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-0aa8877c0c04> in <module>
#       9     save=True,
#      10     outfile_basename="save_local",
# ---> 11     resolution=10,
#      12 )
#
# /opt/conda/lib/python3.7/site-packages/descarteslabs/client/services/raster/raster.py in raster(self, inputs, bands, scales, data_type, output_format, srs, dimensions, resolution, bounds, bounds_srs, cutline, place, align_pixels, resampler, dltile, processing_level, save, outfile_basename, **pass_through_params)
#     536                 params["dltile"] = dltile
#     537
# --> 538         r = self.session.post("/raster", json=params)
#     539
#     540         raw = BytesIO(r.content)
#
# /opt/conda/lib/python3.7/site-packages/requests/sessions.py in post(self, url, data, json, **kwargs)
#     588         """
#     589
# --> 590         return self.request('POST', url, data=data, json=json, **kwargs)
#     591
#     592     def put(self, url, data=None, **kwargs):
#
# /opt/conda/lib/python3.7/site-packages/descarteslabs/client/services/service/service.py in request(self, method, url, **kwargs)
#     189         kwargs[self.ATTR_HEADERS][HttpHeaderKeys.RequestGroup] = uuid.uuid4().hex
#     190
# --> 191         resp = super(Session, self).request(method, self.base_url + url, **kwargs)
#     192
#     193         if (
#
# /opt/conda/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     526             hooks=hooks,
#     527         )
# --> 528         prep = self.prepare_request(req)
#     529
#     530         proxies = proxies or {}
#
# /opt/conda/lib/python3.7/site-packages/requests/sessions.py in prepare_request(self, request)
#     464             auth=merge_setting(auth, self.auth),
#     465             cookies=merged_cookies,
# --> 466             hooks=merge_hooks(request.hooks, self.hooks),
#     467         )
#     468         return p
#
# /opt/conda/lib/python3.7/site-packages/requests/models.py in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     317         self.prepare_headers(headers)
#     318         self.prepare_cookies(cookies)
# --> 319         self.prepare_body(data, files, json)
#     320         self.prepare_auth(auth, url)
#     321
#
# /opt/conda/lib/python3.7/site-packages/requests/models.py in prepare_body(self, data, files, json)
#     467             # provides this natively, but Python 3 gives a Unicode string.
#     468             content_type = 'application/json'
# --> 469             body = complexjson.dumps(json)
#     470             if not isinstance(body, bytes):
#     471                 body = body.encode('utf-8')
#
# /opt/conda/lib/python3.7/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     229         cls is None and indent is None and separators is None and
#     230         default is None and not sort_keys and not kw):
# --> 231         return _default_encoder.encode(obj)
#     232     if cls is None:
#     233         cls = JSONEncoder
#
# /opt/conda/lib/python3.7/json/encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# /opt/conda/lib/python3.7/json/encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# /opt/conda/lib/python3.7/json/encoder.py in default(self, o)
#     177
#     178         """
# --> 179         raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                         f'is not JSON serializable')
#     181
#
# TypeError: Object of type ImageResult is not JSON serializable

# %% [markdown]
# This map shows Sentinel-2 provides cloud free before/after imagery from 24th July and 18th August 2020. Sentinel-2 contains 13 bands with resolution varying from 10m to 60m. See [Copernicus website](https://sentinels.copernicus.eu/web/sentinel/user-guides/sentinel-2-msi/resolutions/spatial) or [Descartes catalog](https://catalog.descarteslabs.com/?/product/sentinel-2:L1C) for full details.
# <a id='sentinel1'></a>
# ### Sentinel-1

# %%
# Initialise map
m5 = wf.interactive.MapApp()
m5.center, m5.zoom = (lat, lon), zoom

satellite, bands = "sentinel-1:GRD", ['vh','vv']
st_date, end_date = ['2020-07-30T00:00:00.000Z', '2020-08-05T00:00:00.000Z'], ['2020-07-30T14:00:00.000Z', '2020-08-05T14:00:00.000Z'] # Timeframes for before-after imagery: start 1, start 2; end 1 ,end 2

# Loop over dates (time 1 & time 2)
for i in range(len(st_date)):
    getImage(satellite, bands, st_date, end_date, i, 1, m5)
    for j in bands:
        getImage(satellite, j, st_date, end_date, i, 1, m5)

m5
# Out:
# `ipyleaflet` and/or `ipywidgets` Jupyter extensions are not installed! (or you're not in a Jupyter notebook.)
# To install for JupyterLab, run this in a cell:
#     !jupyter labextension install jupyter-leaflet @jupyter-widgets/jupyterlab-manager
# To install for plain Jupyter Notebook, run this in a cell:
#     !jupyter nbextension enable --py --sys-prefix ipyleaflet
# Then, restart the kernel and refresh the webpage.

# %% [markdown]
# Sentinel-1 has clear before/after radar imagery from 30th July and 5th August 2020. Sentinel-1 contains 2 bands (vv & vh) with 20m resolution. See [Copernicus website](https://sentinels.copernicus.eu/web/sentinel/user-guides/sentinel-1-sar) or [Descartes catalog](https://catalog.descarteslabs.com/?/product/sentinel-1:GRD) for full details.
# <a id='highResolution'></a>
# ### High Resolution Imagery
# Firstly PlanetLabs SkySat have a very limited amount of high resolution imagery available on Google Earth Engine, shown in the next 3 figures, from prior to the explosion:
# - [SkySat RGB](https://code.earthengine.google.com/6f8de4d7a3f11a4caffe73d61372716b) - 0.8m resolution
# - [SkySat Panchromatic](https://code.earthengine.google.com/4470ae2335bc561c12a4824e72e4fb87) - 0.8m resolution
# - [SkySat Multispectral](https://code.earthengine.google.com/2b11bfafc355dfa68b313b1622149fba) - 1m resolution
#
# We do not have high-resolution imagery available for after the explosion so the use of these by themselves may be limited. Will high resolution imagery be available in the immediate aftermath of disasters, or would rights issues hinder progress?
# We should ask ESA about availability of high-resolution mapping in immediate aftermath of disasters within [Copernicus EMS](https://emergency.copernicus.eu/).

# %%
# RGB Map
hrMap1 = geemap.Map()
dataset = ee.ImageCollection('SKYSAT/GEN-A/PUBLIC/ORTHO/RGB')
rgb = dataset.select(['R', 'G', 'B']);
rgbVis = {min: 11.0, max: 190.0}
hrMap1.setCenter(35.5063, 33.8975, 14)
hrMap1.addLayer(rgb, rgbVis, 'RGB')
display(hrMap1)
# Out:
# Map(center=[33.8975, 35.5063], controls=(WidgetControl(options=['position'], widget=HBox(children=(ToggleButto…

# %%
# Panchromatic Map
hrMap2 = geemap.Map()
dataset = ee.ImageCollection('SKYSAT/GEN-A/PUBLIC/ORTHO/MULTISPECTRAL')
falseColor = dataset.select(['P'])
falseColorVis = {min: 200, max: 6000}
hrMap2.setCenter(35.5063, 33.8975, 14)
hrMap2.addLayer(falseColor, falseColorVis, 'False Color')
display(hrMap2)
# Out:
# Map(center=[33.8975, 35.5063], controls=(WidgetControl(options=['position'], widget=HBox(children=(ToggleButto…

# %%
# Multispectral Map
hrMap3 = geemap.Map()
dataset = ee.ImageCollection('SKYSAT/GEN-A/PUBLIC/ORTHO/MULTISPECTRAL')
falseColor = dataset.select('N')
falseColorVis = {min: 200, max: 6000}
hrMap3.setCenter(35.5063, 33.8975, 14)
hrMap3.addLayer(falseColor, falseColorVis, 'False Color')
display(hrMap3)
# Out:
# Map(center=[33.8975, 35.5063], controls=(WidgetControl(options=['position'], widget=HBox(children=(ToggleButto…

# %% [markdown]
# ### High Resolution from DLR
# * Folder 1 - Not Beirut but ~30km north east on 20th July -> not useful
# * Folder 2 - 1.6GB image of Beirut and stretching some way south on 20th August -> After shot
# * Folder 3 - 600MB image of Beirut (cuts just west of the port on 5th August -> Good after shot
# * Folder 4 - Same location as F3 - 6th August
# * Folder 5 - Central Beirut - 31st July

# %%
img = "data/highRes/20AUG05084637-S2AS-MEDIA-Beirut-AUG05-25km.TIF"

# import imports as ip
# im = ip.image_to_df(img,'label')
#im.plot.imshow()

# %%
import rioxarray as rxr
import matplotlib.pyplot as plt
wholeIfg = rxr.open_rasterio(img, masked=True).squeeze()

# Plot AOI on whole interferogram
#f, ax = plt.subplots(figsize=(10, 5))
#wholeIfg.indexes
wholeIfg.values.mean()
#plt.show()
# Out:
# 252.05661

# %% [markdown]
# ______________
# <a id='groundImagery'></a>
# ## 4 - Ground Imagery
# <a id='geopalImagery'></a>
# ### SARAID Imagery from GeoPal

# %%
located.head()

# %% [markdown]
# <a id='mapillary'></a>
# ### Mapillary
# Let's now try importing from Mapillary. First we'll get a map showing imagery locations before and after the explosion. Secondly we'll get a sample image.

# %%
# First we download all the image locations and properties for our area and dates of interest
def to_geodata(filename, color):
    images = gpd.read_file(filename)
    timedImages = GeoData(geo_dataframe = images,
                          style={'color': color, 'radius':2, 'fillColor': color, 'opacity':0.2, 'weight':1.9, 'dashArray':'2', 'fillOpacity':0.2},
                          hover_style={'fillColor': 'white' , 'fillOpacity': 0.2},
                          point_style={'radius': 3, 'color': color, 'fillOpacity': 0.2, 'fillColor': color, 'weight': 3},
                          name = 'Images')
    return timedImages

for i in range(len(m_st_date)):
    filename = mapillaryPath+m_st_date[i]+'-'+m_end_date[i]+'.geojson'
    
    if not os.path.exists(filename):  
        # create an empty GeoJSON to collect all images we find
        output = {"type":"FeatureCollection","features":[]}
        with open(filename, 'w') as outfile:
            # Make API call for images within dates
            url = ('https://a.mapillary.com/v3/images?client_id={}&bbox={}&start_time={}&end_time={}&per_page=1000').format(client_id,bbox,m_st_date[i],m_end_date[i]) 
            r = requests.get(url, timeout=None) # get the request with no timeout in case API is slow
            while r.status_code != 200: r = requests.get(url, timeout=None) # check if request failed, if failed, keep trying - 200 is a success

            # Get first data in to output json
            data = r.json() # get a JSON format of the response
            data_length = len(data['features']) # get a count of how many images 
            for feature in data['features']: output['features'].append(feature) # append each image to our empty geojson

            # if we receive 500 items, response was full and should be a next page
            while data_length == 1000:

                link = r.links['next']['url'] # get the URL for a next page
                r = requests.get(link) # retrieve the next page in JSON format
                while r.status_code != 200: r = requests.get(url, timeout=None) # try again if the request fails

                data = r.json()
                for feature in data['features']: output['features'].append(feature)

                print('Total images: {}'.format(len(output['features']))) # print total count
                data_length = len(data['features']) #update data length

            # save the entire JSON response as a geojson for outside use
            json.dump(output, outfile)
     
    if not i: preImages = to_geodata(filename,'green')
    else: postImages = to_geodata(filename, 'red')

# %%
# Let's take a quick look at the format of the images
preImages.geo_dataframe.head()
# Out:
#           ca camera_make camera_model          captured_at  \
# 0   0.000000       Apple    iPhone XR  2020-04-27T16:28:02
# 1  30.863913       Apple    iPhone XR  2020-04-27T16:28:01
# 2  35.477667       Apple    iPhone XR  2020-04-27T16:28:00
# 3  36.101565       Apple    iPhone XR  2020-04-27T16:27:59
# 4  34.715559       Apple    iPhone XR  2020-04-27T16:27:58
#
#                       key   pano            sequence_key  \
# 0  lRaJxclrODcjdPj4Q07zbg  False  8cu6lqmeh9avh4eolkusld
# 1  KTehUzug09w__Ctz8dGmbg  False  8cu6lqmeh9avh4eolkusld
# 2  QV2tOLuwn0cEidV0kzx4JA  False  8cu6lqmeh9avh4eolkusld
# 3  ZQflQMWUnPRIsCebag-yCA  False  8cu6lqmeh9avh4eolkusld
# 4  Gw7EbQF4ccIK7h8_CTM6Ng  False  8cu6lqmeh9avh4eolkusld
#
#                  user_key username  quality_score organization_key private  \
# 0  ANHxhrNI7u3GxCpl19mbeQ    ziadg              5             None    None
# 1  ANHxhrNI7u3GxCpl19mbeQ    ziadg              5             None    None
# 2  ANHxhrNI7u3GxCpl19mbeQ    ziadg              3             None    None
# 3  ANHxhrNI7u3GxCpl19mbeQ    ziadg              3             None    None
# 4  ANHxhrNI7u3GxCpl19mbeQ    ziadg              5             None    None
#
#                         geometry
# 0  POINT (35.5320788 33.8864233)
# 1  POINT (35.5320788 33.8864233)
# 2  POINT (35.5319948 33.8863067)
# 3  POINT (35.5318928 33.8861879)
# 4  POINT (35.5317895 33.8860703)

# %%
# Quick Map just showing locations - go to next for full marker map
m6 = Map(basemap=basemaps.OpenStreetMap.Mapnik, center=[lat, lon], zoom=zoom, scroll_wheel_zoom=True)
m6.add_layer(preImages)
m6.add_layer(postImages)
if not 'l6' in globals(): # Add legend if forming map for first time
    l6 = legend = LegendControl({"Pre Explosion":"#008000", "Post Explosion":"#FF0000"}, name="Image Locations", position="bottomleft")
    m6.add_control(l6)

m6
# Out:
# Map(center=[33.8975, 35.5063], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zo…

# %%
# Create Map with interactive markers - this will take ages, try the HTML version from the Google Drive
m7 = Map(basemap=basemaps.OpenStreetMap.Mapnik, center=[lat, lon], zoom=zoom, scroll_wheel_zoom=True)

# Create marker for each point
for j in [preImages, postImages]:
    images = j.geo_dataframe
    color = 'green' if j is preImages else 'red'
    for i in tqdm(images.index):
        a = images.loc[i]
        location = (a.geometry.y,a.geometry.x)
        marker = CircleMarker(location=location, radius = 3, color=color, fill_color=color, 
                              fill_opacity=0.8, opacity=0.6)

        # Popup associated to a layer
        msg = HTML()
        msg.value = ("Date: {}<br>"
                     "Quality: {}<br>"
                     "Pano: {}<br>"
                     "Camera:{}<br>"
                     "Key: {}<br>").format(a.captured_at,a.quality_score,a.pano,a.camera_model,a.key)
        marker.popup = msg
        m7.add_layer(marker)

if not 'l7' in globals(): # Add legend if forming map for first time
    l7 = legend = LegendControl({"Pre Explosion":"#008000", "Post Explosion":"#FF0000"}, name="Image Locations", position="bottomleft")
    m7.add_control(l7)

display(m7)
m7.save('./data/mapillaryImagesMap.html', title='Mapillary Map') # Save map for quick interaction in HTML
# Out:
# 100%|██████████| 29165/29165 [1:11:17<00:00,  6.82it/s]
# 100%|██████████| 12475/12475 [1:11:29<00:00,  2.91it/s]
# Map(center=[33.8975, 35.5063], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zo…

# %%
# Display Mapillary Image by defining index or image_key
image_index = 100 # Define Index
image_key = False # Or replace this directly with key found on map
link = 'https://images.mapillary.com/{}/thumb-1024.jpg'.format(preImages.geo_dataframe.loc[image_index].key if not image_key else image_key)
print(link, 'image key: {}'.format(preImages.geo_dataframe.loc[image_index].key if not image_key else image_key))

# request the image URL, to get a displayable image
display(Image(requests.get(link,stream=all).content))
# Out:
# https://images.mapillary.com/GJxrJds217zX2offqGr7EA/thumb-1024.jpg image key: GJxrJds217zX2offqGr7EA

# %% [markdown]
# _______________
# ## 5 - Houston Data

# %%
from PIL import Image
im = Image.open('./data/2018IEEE_Contest/Phase2/FullHSIDataset/20170218_UH_CASI_S4_NAD83.pix')
plt.imshow(np.array(im))
plt.title('HR Imagery')
# plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# <ipython-input-30-f7db0c353258> in <module>
#       1 from PIL import Image
# ----> 2 im = Image.open('./data/2018IEEE_Contest/Phase2/FullHSIDataset/20170218_UH_CASI_S4_NAD83.pix')
#       3 plt.imshow(np.array(im))
#       4 plt.title('HR Imagery')
#       5 # plt.colorbar()
#
# /opt/conda/lib/python3.7/site-packages/PIL/Image.py in open(fp, mode, formats)
#    2957         warnings.warn(message)
#    2958     raise UnidentifiedImageError(
# -> 2959         "cannot identify image file %r" % (filename if filename else fp)
#    2960     )
#    2961
#
# UnidentifiedImageError: cannot identify image file './data/2018IEEE_Contest/Phase2/FullHSIDataset/20170218_UH_CASI_S4_NAD83.pix'
